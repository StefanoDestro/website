# %% [markdown]
# ## Codice per produrre wedding

# %%
#QUESTO CODICE E' SOLO PER I WEDDING (SIA ITA CHE ENG)! SE DEVI PRODURRE FAMILY SESSION O COPPIE, VAI A CODICI PIU' IN BASSO
def generate_html():
    html_snippet = '''
        <a data-fancybox="gallery" class="flo-block-gallery-view-2__image to-appear-disabled"
            href="{href}"
            data-thumb="{data_thumb}">
            <img class="flo-block-gallery-view-2__image-thumb loaded"
                src="{src}"
                sizes="(max-width: 768px) 300px, (max-width: 1024px) 273px, 100vw" alt="wedding photography photographer italian stefano destro" srcset="{srcset}">
        </a>
    '''
    
    name1 = input("Inserisci il nome del primo sposo/a (usa *solo* lettere minuscole, niente spazi): ")
    name2 = input("Inserisci il nome del secondo sposo/a (usa *solo* lettere minuscole, niente spazi): ")
    x = int(input(f"Inserisci il numero di foto del catalogo di {name1} e {name2}: "))
    
    initial_path = f"../images/portfolio/{name1}{name2}/{name1}{name2}_1.jpg"

    for i in range(1, x + 1):
        current_path = initial_path.replace(f'{name1}{name2}_1.jpg', f'{name1}{name2}_{i}.jpg')

        current_html = html_snippet.format(
            href=current_path,
            data_thumb=current_path,
            src=current_path,
            srcset=current_path
        )

        print(current_html)

# Example usage with user input
generate_html()
# Out:
#         <a data-fancybox="gallery" class="flo-block-gallery-view-2__image to-appear-disabled"
#             href="../images/portfolio/martaluigi/martaluigi_1.jpg"
#             data-thumb="../images/portfolio/martaluigi/martaluigi_1.jpg">
#             <img class="flo-block-gallery-view-2__image-thumb loaded"
#                 src="../images/portfolio/martaluigi/martaluigi_1.jpg"
#                 sizes="(max-width: 768px) 300px, (max-width: 1024px) 273px, 100vw" alt="wedding photography photographer italian stefano destro" srcset="../images/portfolio/martaluigi/martaluigi_1.jpg">
#         </a>
#
#
#         <a data-fancybox="gallery" class="flo-block-gallery-view-2__image to-appear-disabled"
#             href="../images/portfolio/martaluigi/martaluigi_2.jpg"
#             data-thumb="../images/portfolio/martaluigi/martaluigi_2.jpg">
#             <img class="flo-block-gallery-view-2__image-thumb loaded"
#                 src="../images/portfolio/martaluigi/martaluigi_2.jpg"
# ...

# %% [markdown]
# ## Codice per produrre Family Sesssion

# %%
#QUESTO CODICE E' SOLO PER FAMILY SESSION! SE DEVI PRODURRE WEDDING VAI SOPRA, SE COPPIE, VAI A CODICI PIU' IN BASSO
def generate_html():
    html_snippet = '''
        <a data-fancybox="gallery" class="flo-block-gallery-view-2__image to-appear-disabled"
            href="{href}"
            data-thumb="{data_thumb}">
            <img class="flo-block-gallery-view-2__image-thumb loaded"
                src="{src}"
                sizes="(max-width: 768px) 300px, (max-width: 1024px) 273px, 100vw" alt="wedding photography photographer italian stefano destro" srcset="{srcset}">
        </a>
    '''
    
    name1 = input("Inserisci il nome del primo sposo/a (usa *solo* lettere minuscole, niente spazi): ")
    name2 = input("Inserisci il nome del secondo sposo/a (usa *solo* lettere minuscole, niente spazi): ")
    x = int(input(f"Inserisci il numero di foto del catalogo di {name1} e {name2}: "))
    
    initial_path = f"../images/familysession/{name1}{name2}/{name1}{name2}_1.jpg"

    for i in range(1, x + 1):
        current_path = initial_path.replace(f'{name1}{name2}_1.jpg', f'{name1}{name2}_{i}.jpg')

        current_html = html_snippet.format(
            href=current_path,
            data_thumb=current_path,
            src=current_path,
            srcset=current_path
        )

        print(current_html)

# Example usage with user input
generate_html()
# Out:
#         <a data-fancybox="gallery" class="flo-block-gallery-view-2__image to-appear-disabled"
#             href="../images/familysession/fulviacesare/fulviacesare_1.jpg"
#             data-thumb="../images/familysession/fulviacesare/fulviacesare_1.jpg">
#             <img class="flo-block-gallery-view-2__image-thumb loaded"
#                 src="../images/familysession/fulviacesare/fulviacesare_1.jpg"
#                 sizes="(max-width: 768px) 300px, (max-width: 1024px) 273px, 100vw" alt="wedding photography photographer italian stefano destro" srcset="../images/familysession/fulviacesare/fulviacesare_1.jpg">
#         </a>
#
#
#         <a data-fancybox="gallery" class="flo-block-gallery-view-2__image to-appear-disabled"
#             href="../images/familysession/fulviacesare/fulviacesare_2.jpg"
#             data-thumb="../images/familysession/fulviacesare/fulviacesare_2.jpg">
#             <img class="flo-block-gallery-view-2__image-thumb loaded"
# ...

# %% [markdown]
# ## Codice per produrre Stories

# %%
#QUESTO CODICE E' SOLO PER STORIES! SE DEVI PRODURRE WEDDING VAI SOPRA
def generate_html():
    html_snippet = '''
        <a data-fancybox="gallery" class="flo-block-gallery-view-2__image to-appear-disabled"
            href="{href}"
            data-thumb="{data_thumb}">
            <img class="flo-block-gallery-view-2__image-thumb loaded"
                src="{src}"
                sizes="(max-width: 768px) 300px, (max-width: 1024px) 273px, 100vw" alt="wedding photography photographer italian stefano destro" srcset="{srcset}">
        </a>
    '''
    
    name1 = input("Inserisci il nome del primo sposo/a (usa *solo* lettere minuscole, niente spazi): ")
    name2 = input("Inserisci il nome del secondo sposo/a (usa *solo* lettere minuscole, niente spazi): ")
    x = int(input(f"Inserisci il numero di foto del catalogo di {name1} e {name2}: "))
    
    initial_path = f"../images/stories/{name1}{name2}/{name1}{name2}_1.jpg"

    for i in range(1, x + 1):
        current_path = initial_path.replace(f'{name1}{name2}_1.jpg', f'{name1}{name2}_{i}.jpg')

        current_html = html_snippet.format(
            href=current_path,
            data_thumb=current_path,
            src=current_path,
            srcset=current_path
        )

        print(current_html)

# Example usage with user input
generate_html()
# Out:
#         <a data-fancybox="gallery" class="flo-block-gallery-view-2__image to-appear-disabled"
#             href="../images/stories/courtneyfamily/courtneyfamily_1.jpg"
#             data-thumb="../images/stories/courtneyfamily/courtneyfamily_1.jpg">
#             <img class="flo-block-gallery-view-2__image-thumb loaded"
#                 src="../images/stories/courtneyfamily/courtneyfamily_1.jpg"
#                 sizes="(max-width: 768px) 300px, (max-width: 1024px) 273px, 100vw" alt="wedding photography photographer italian stefano destro" srcset="../images/stories/courtneyfamily/courtneyfamily_1.jpg">
#         </a>
#
#
#         <a data-fancybox="gallery" class="flo-block-gallery-view-2__image to-appear-disabled"
#             href="../images/stories/courtneyfamily/courtneyfamily_2.jpg"
#             data-thumb="../images/stories/courtneyfamily/courtneyfamily_2.jpg">
#             <img class="flo-block-gallery-view-2__image-thumb loaded"
# ...

# %% [markdown]
# 60 SECONDS

# %%
def generate_html():
    html_snippet = '''
    <a href="{href}" data-fancybox="gallery-desktop" data-caption="">
      <img src="{src}" alt="">
    </a>
        
    '''
    
    name1 = input("Inserisci il nome del primo sposo/a (usa *solo* lettere minuscole, niente spazi): ")
    name2 = input("Inserisci il nome del secondo sposo/a (usa *solo* lettere minuscole, niente spazi): ")
    x = int(input(f"Inserisci il numero di foto del catalogo di {name1} e {name2}: "))
    
    initial_path = f"../images/{name1}{name2}/desktop/{name1}{name2}_1.jpg"

    for i in range(1, x + 1):
        current_path = initial_path.replace(f'{name1}{name2}_1.jpg', f'{name1}{name2}_{i}.jpg')

        current_html = html_snippet.format(
            href=current_path,
            data_thumb=current_path,
            src=current_path,
            srcset=current_path
        )

        print(current_html)

# Example usage with user input
generate_html()
# Out:
#     <a href="../images/60seconds/desktop/60seconds_1.jpg" data-fancybox="gallery-desktop" data-caption="">
#       <img src="../images/60seconds/desktop/60seconds_1.jpg" alt="">
#     </a>
#
#
#
#     <a href="../images/60seconds/desktop/60seconds_2.jpg" data-fancybox="gallery-desktop" data-caption="">
#       <img src="../images/60seconds/desktop/60seconds_2.jpg" alt="">
#     </a>
#
#
#
#     <a href="../images/60seconds/desktop/60seconds_3.jpg" data-fancybox="gallery-desktop" data-caption="">
#       <img src="../images/60seconds/desktop/60seconds_3.jpg" alt="">
#     </a>
#
#
#
#     <a href="../images/60seconds/desktop/60seconds_4.jpg" data-fancybox="gallery-desktop" data-caption="">
#       <img src="../images/60seconds/desktop/60seconds_4.jpg" alt="">
#     </a>
#
#
#
#     <a href="../images/60seconds/desktop/60seconds_5.jpg" data-fancybox="gallery-desktop" data-caption="">
#       <img src="../images/60seconds/desktop/60seconds_5.jpg" alt="">
#     </a>
#
#
#
# ...
